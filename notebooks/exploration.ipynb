# %% [markdown]
# # ClinOps — Exploration
#
# Scratch notebook for exploring the synthetic Synthea FHIR R4 data and feature ideas.
#
# **Synthetic data only — no real patient data / PHI, ever.**
#
# Empty skeleton; nothing implemented yet.
